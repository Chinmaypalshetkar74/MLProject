# %% [markdown]
# # student performance indicator

# %% [markdown]
# ### Life cycle of machine learning project
#
# * Understanding problem statement
# * data collection
# * data checks to performace
# * exploratory data analysis (EDA)
# * data pre- processinng
# * model traning
# * Choose best model

# %% [markdown]
# ## 1)  problem Statement
# * this project understand how student performance (test score ) is affected by other variables such as Gender .Ethnicity ,parental level of education , Lunch and test preparation course

# %% [markdown]
# ## 2) data collection
# *data source=https://www.kaggle.com/datasets/spscientist/students-performance-in-exams?datasets=74977
#
# *data consist 8 column and 1000rows

# %% [markdown]
# ## 2.1 Import required data packages
# import numpy pandas matplotllib.pyplot seaborn and Warning library

# %%
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import pandas as pd 
import warnings 
warning.filterwarnings('ignore')
# Out:
# The kernel failed to start as ' C extension module was built for another version of psutil (5.9.0 instead of 6.0.0); you may try to ' could not be imported from '5.9.0 instead of 6.0.0'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %% [markdown]
# #### conda install -p c:\Project\venv ipykernel --update-deps --force-reinstall

# %%
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import pandas as pd 
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## import csv data as pandas Dataframe

# %%
df= pd.read_csv('Data/StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# ## Data set information
#
# * gender : sex of students -> (Male/Female)
# * race/ethinicity : ethnicity : parents final Education (bachelore degree some college , master degree , asscociates degree , high school)
# * lunch : having before test (standard or free/reduced)
# * test preparing course : complete or not complete before test
# * math score
# * reducing score
# * writing score

# %% [markdown]
# ## Data checks to Performance

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# there is no missing values in these data set

# %% [markdown]
# ## checks Duplicate

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate values in it

# %% [markdown]
# ## Check data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ### Checking number of unique values of each column

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %% [markdown]
# ## Checking Statastics of The Datasets

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## Insights
#
# * from description of numerical data , all means very close to each other - between 66 and 68.05;
# * All standard deviation  are also close - between 14.6 to 15.19
# * while there is minimum score for 0 for math , for writing minimum is much higher = 10 and for reading myet higher = 17

# %% [markdown]
# ## EXploring the data

# %%
print("Categories in 'gender' Variable: ",end=" ")
print(df['gender'].unique())

print("Categories in 'race/ethnicity' Variable :",end= " ")
print(df['race/ethnicity',].unique())

print("Categories in 'parental level of education' Variable: ",end=" ")
print(df['parental level of education'].unique())

print("Categories in 'lunch' Variable: ",end= " ")
print(df['lunch'].unique())

print("Categories in 'test preparation course' Variable: ",end= " ")
print(df['test preparation course'].unique())
# Out:
# Categories in 'gender' Variable:  ['female' 'male']
# Categories in 'race/ethnicity' Variable :
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Project\venv\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Project\venv\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Project\venv\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('race/ethnicity',)
#
# ...

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
import pandas as pd

df = pd.read_csv('Data/StudentsPerformance.csv')  # Ensure the file is in the correct path

print("Categories in 'gender' Variable: ", end=" ")
print(df['gender'].unique())

print("Categories in 'race/ethnicity' Variable: ", end=" ")
print(df['race/ethnicity'].unique())  # Removed the comma

print("Categories in 'parental level of education' Variable: ", end=" ")
print(df['parental level of education'].unique())

print("Categories in 'lunch' Variable: ", end=" ")
print(df['lunch'].unique())

print("Categories in 'test preparation course' Variable: ", end=" ")
print(df['test preparation course'].unique())
# Out:
# Categories in 'gender' Variable:  ['female' 'male']
# Categories in 'race/ethnicity' Variable:  ['group B' 'group C' 'group A' 'group D' 'group E']
# Categories in 'parental level of education' Variable:  ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# Categories in 'lunch' Variable:  ['standard' 'free/reduced']
# Categories in 'test preparation course' Variable:  ['none' 'completed']

# %%
## Define numerical and categorical Columnms 
numeric_feature= [feature for feature in  df.columns if df[feature].dtype != 'O']
Categorical_feature= [ feature for feature in  df.columns if df[feature].dtype == 'O'] 

# print columns 
print('We have {} numerical feature : {}'.format(len(numeric_feature),numeric_feature))
print('\n WE have {} categorical feature :{}'.format(len(Categorical_feature),Categorical_feature))
# Out:
# We have 3 numerical feature : ['math score', 'reading score', 'writing score']
#
#  WE have 5 categorical feature :['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']

# %% [markdown]
# ## Adding columns for "Total Score" and "Average "

# %%
df['total score'] = df['math score'] + df['reading score']+ df['writing score']
df['average']=df['total score ']/3
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Project\venv\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Project\venv\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Project\venv\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total score '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['total score'] = df['math score'] + df['reading score'] + df['writing score']
df['average'] = df['total score'] / 3  # Removed the extra space
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
reading_full = df[df['reading score'] == 100 ]['average'].count()
writing_full = df[df['writing score'] == 100 ]['average'].count()
Math_full = df[df['math score'] == 100 ]['average'].count()

print(f'Number of students with full marks in maths :{Math_full}')
print(f'Number of students with full marks in writing :{reading_full}')
print(f'Number of students with full marks in reading :{writing_full}')
# Out:
# Number of students with full marks in maths :7
# Number of students with full marks in writing :17
# Number of students with full marks in reading :14

# %%
reading_less_20 = df[df['reading score'] <= 20 ]['average'].count()
writing_less_20 = df[df['writing score'] <= 20 ]['average'].count()
Math_less_20 = df[df['math score'] <= 20 ]['average'].count()

print(f'Number of students with less than 20 marks in maths :{Math_less_20}')
print(f'Number of students with less than 20  marks in writing :{reading_less_20}')
print(f'Number of students with less than 20  marks in reading :{writing_less_20}')
# Out:
# Number of students with less than 20 marks in maths :4
# Number of students with less than 20  marks in writing :1
# Number of students with less than 20  marks in reading :3

# %% [markdown]
# ## Insights
# * from above values we get students have performance worst in maths
# * best performance in reading section

# %% [markdown]
# ## Exploratory Data (Visualization)

# %% [markdown]
# ### Viusual average score distribution to make some conclusion
#
# * Histogram
# * kernel Distribution function (KDE)

# %% [markdown]
# ### Histogram and KDE

# %%
fig, axs= plt.subplot(1,2, figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
plt.subplot(122) 
sns.histplot(data=df,x='average',kde=True,hue='gender')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 fig, axs= plt.subplot(1,2, figsize=(15,7))
#       2 plt.subplot(121)
#       3 sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
#
# File c:\Project\venv\lib\site-packages\matplotlib\pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# File c:\Project\venv\lib\site-packages\matplotlib\gridspec.py:587, in SubplotSpec._from_subplot_args(figure, args)
#     585     rows, cols, num = args
#     586 else:
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(1, 2, figsize=(15, 7))  # Use plt.subplots instead of plt.subplot

# First subplot
sns.histplot(data=df, x='average', bins=30, kde=True, color='g', ax=axs[0])  
axs[0].set_title("Distribution of Average Scores")

# Second subplot
sns.histplot(data=df, x='average', kde=True, hue='gender', ax=axs[1])  
axs[1].set_title("Average Scores by Gender")

plt.show()

# %% [markdown]
# ## Insights

# %% [markdown]
# * Female students tend to perform well then male students .

# %%
plt.subplots(1,3,figsize=(26,6))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='lunch')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='lunch')
plt.show()

# %% [markdown]
# ## insights
# * Standard lunch helps perform well in exam
# * Standard lunch helps perform well in exam be it male or female

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## insights
# * in general parent education dont help student perform well in exam
# * 2nd plot shows that parental whose describe education of asscociate degree or master their male child tend performance well in exam
# * 3rd plot wecan see there is no effect of parent education on female student
